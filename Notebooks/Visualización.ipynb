# %%
import seaborn as sns

import pandas as pd

# %%
# Hipótesis: Florida es el area donde más ataque hay porque la mayoría son provocados

# %%
attacks_6 = pd.read_csv('attacks_4.csv')

# %%
attacks_6
# Out:
#       Unnamed: 0         Date  Year        Type             Country  \
# 0              0  25-Jun-2018  2018        Boat                 USA
# 1              1  18-Jun-2018  2018  Unprovoked                 USA
# 2              2  09-Jun-2018  2018     Invalid                 USA
# 3              3  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4              4  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297        6297  Before 1903     0  Unprovoked           AUSTRALIA
# 6298        6298  Before 1903     0  Unprovoked           AUSTRALIA
# 6299        6299    1900-1905     0  Unprovoked                 USA
# 6300        6300    1883-1889     0  Unprovoked              PANAMA
# 6301        6301    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
attacks_6.Area.value_counts()
# Out:
# Florida                                           1037
# New South Wales                                    486
# 0                                                  455
# Queensland                                         311
# Hawaii                                             298
#                                                   ...
# Conservatória District                               1
# Western Caroline Islands (North Pacific Ocean)       1
#  Upolu Island                                        1
# Naples Province                                      1
# Hokkaido Prefecture                                  1
# Name: Area, Length: 826, dtype: int64

# %%
# Desmiento la hipotesis
attacks_6[attacks_6.Area=='Florida'].Type.mode()
# Out:
# 0    Unprovoked
# dtype: object

# %%
data = attacks_6[attacks_6.Area=='Florida']
data
# Out:
#       Unnamed: 0                   Date  Year        Type Country     Area  \
# 7              7            27-May-2018  2018  Unprovoked     USA  Florida
# 8              8            26-May-2018  2018  Unprovoked     USA  Florida
# 9              9            26-May-2018  2018  Unprovoked     USA  Florida
# 61            61            18-Nov-2017  2017  Unprovoked     USA  Florida
# 69            69            23-Oct-2017  2017  Unprovoked     USA  Florida
# ...          ...                    ...   ...         ...     ...      ...
# 6217        6217                No date     0  Unprovoked     USA  Florida
# 6226        6226  No date, Before  1975     0    Provoked     USA  Florida
# 6233        6233   No date, Before 1902     0  Unprovoked     USA  Florida
# 6249        6249            Before 1958     0  Unprovoked     USA  Florida
# 6283        6283            Before 1921     0  Unprovoked     USA  Florida
#
#                                                Location  \
# ...

# %%
sns.countplot(x=data.Type)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
# Hipótesis: florida es la zona donde más ataques a surfistas hay y la mayoria son a hombres porque los hombres surfean más que las mujeres

# %%
attacks_6[attacks_6.Activity=='Surfing'].Area.mode()
# Out:
# 0    Florida
# dtype: object

# %%
attacks_6[attacks_6.Area=='Florida'].Sex.mode()
# Out:
# 0    M
# dtype: object

# %%
data_=attacks_6[attacks_6.Activity=='Surfing']

# %%
sns.countplot(x=data_.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# Podría ser cierta la hipótesis porque la mayoría de los ataques a surfistas son a hombres y eso puede llevar a que los hombres surfeen más que las mujeres
