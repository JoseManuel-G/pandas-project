# %%
import seaborn as sns

import pandas as pd

# %%
attacks_4 = pd.read_csv('attacks_4.csv')

# %%
attacks_4
# Out:
#       Unnamed: 0         Date  Year        Type             Country  \
# 0              0  25-Jun-2018  2018        Boat                 USA
# 1              1  18-Jun-2018  2018  Unprovoked                 USA
# 2              2  09-Jun-2018  2018     Invalid                 USA
# 3              3  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4              4  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297        6297  Before 1903     0  Unprovoked           AUSTRALIA
# 6298        6298  Before 1903     0  Unprovoked           AUSTRALIA
# 6299        6299    1900-1905     0  Unprovoked                 USA
# 6300        6300    1883-1889     0  Unprovoked              PANAMA
# 6301        6301    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
attacks_5 = attacks_4.drop(['Unnamed: 0'], axis=1)

# %%
attacks_5.Area.mode()
# Out:
# 0    Florida
# dtype: object

# %%
attacks_5[attacks_5.Activity=='Surfing'].shape[0]
# Out:
# 17

# %%
data = attacks_5[attacks_5.Area=='Florida']
data
# Out:
#              Date  Year        Type Country     Area  \
# 1718  22-Nov-2003  2003  Unprovoked     USA  Florida
# 1214  28-Aug-2008  2008  Unprovoked     USA  Florida
# 1835  14-Aug-2002  2002  Unprovoked     USA  Florida
# 2220  21-Oct-1997  1997  Unprovoked     USA  Florida
# 2391  13-Apr-1995  1995  Unprovoked     USA  Florida
# 2249  09-Jun-1997  1997  Unprovoked     USA  Florida
# 2771  21-Jul-1987  1987  Unprovoked     USA  Florida
# 1114  05-Jul-2009  2009  Unprovoked     USA  Florida
# 2625  30-Aug-1990  1990     Invalid     USA  Florida
# 5314  23-Jun-1916  1916    Provoked     USA  Florida
# 1022  10-Jun-2010  2010  Unprovoked     USA  Florida
# 1331  16-Sep-2007  2007  Unprovoked     USA  Florida
# 995   18-Aug-2010  2010  Unprovoked     USA  Florida
# 167   27-Mar-2017  2017  Unprovoked     USA  Florida
#
#                                                Location         Activity Sex  \
# 1718                      Daytona Beach, Volusia County          Surfing   F
# ...

# %%
data.Activity.mode()
# Out:
# 0    Surfing
# dtype: object

# %%
sns.countplot(x=data.Activity)
# Out:
# <AxesSubplot:xlabel='Activity', ylabel='count'>

# %%
data_1 = attacks_5[attacks_5.Activity=='Surfing']
data_1
# Out:
#               Date  Year        Type       Country             Area  \
# 726    30-Oct-2012  2012  Unprovoked           USA       California
# 1718   22-Nov-2003  2003  Unprovoked           USA          Florida
# 1613   04-Feb-2005  2005  Unprovoked        BRAZIL            Bahia
# 1214   28-Aug-2008  2008  Unprovoked           USA          Florida
# 1835   14-Aug-2002  2002  Unprovoked           USA          Florida
# 2124   01-May-1999  1999  Unprovoked        BRAZIL       Pernambuco
# 2220   21-Oct-1997  1997  Unprovoked           USA          Florida
# 1884   30-Jan-2002  2002  Unprovoked     AUSTRALIA  New South Wales
# 707    25-Jan-2013  2013  Unprovoked     AUSTRALIA       Queensland
# 2249   09-Jun-1997  1997  Unprovoked           USA          Florida
# 2771   21-Jul-1987  1987  Unprovoked           USA          Florida
# 637    18-Aug-2013  2013  Unprovoked           USA           Hawaii
# 549    01-Jun-2014  2014  Unprovoked     AUSTRALIA  New South Wales
# ...

# %%
data_1.Area.mode()
# Out:
# 0    Florida
# dtype: object

# %%
data_1.Sex.mode()
# Out:
# 0    M
# dtype: object

# %%
sns.countplot(x=data_1.Area, hue=data_1.Sex)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='count'>

# %%
attacks_5.Country.mode()
attacks_5.Activity.mode()
# Out:
# 0    Surfing
# dtype: object

# %%
attacks_5 = attacks_5.sample(100)
attacks_5
# Out:
#              Date  Year        Type        Country            Area  \
# 2064  15-Mar-2000  2000  Unprovoked  NEW CALEDONIA  North Province
# 726   30-Oct-2012  2012  Unprovoked            USA      California
# 6145         1776  1776        Boat      GREENLAND               0
# 5913  01-Jun-1870  1870  Unprovoked          INDIA     West Bengal
# 1718  22-Nov-2003  2003  Unprovoked            USA         Florida
# ...           ...   ...         ...            ...             ...
# 325   19-Dec-2015  2015  Unprovoked          ARUBA               0
# 895   15-Jul-2011  2011        Boat        REUNION    Saint-Gilles
# 995   18-Aug-2010  2010  Unprovoked            USA         Florida
# 167   27-Mar-2017  2017  Unprovoked            USA         Florida
# 3515  15-Aug-1967  1967  Unprovoked        BERMUDA        Hamilton
#
#                                    Location                 Activity Sex Age  \
# 2064                                   Poum             Spearfishing   M  35
# ...

# %%
sns.countplot(x=attacks_5.Country)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
set(attacks_5['Country'])
# Out:
# {' PHILIPPINES',
#  ' TONGA',
#  '0',
#  'ADMIRALTY ISLANDS',
#  'AFRICA',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANDAMAN ISLANDS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COMOROS',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
# ...
